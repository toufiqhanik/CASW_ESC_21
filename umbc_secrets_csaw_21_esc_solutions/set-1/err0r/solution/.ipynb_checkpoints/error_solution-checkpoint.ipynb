# %%
SCOPETYPE = 'CWNANO'
PLATFORM = 'CWNANO'
# %run "../../../jupyter/Setup_Scripts/Setup_Generic.ipynb"
scope._cwusb.usbtx.rep = 0x81
scope._cwusb.usbtx.wep = 0x02

# %%
fw_path = "./err0r/err0r-CWNANO.hex"
cw.program_target(scope, cw.programmers.STM32FProgrammer, fw_path)

# %%
def reboot_flush():
    scope.io.nrst = False
    time.sleep(0.05)
    scope.io.nrst = "high_z"
    time.sleep(0.05)
    #Flush garbage too
    target.flush()

# %%
import matplotlib.pyplot as plt
import numpy as np
win_codes=[[],[],[],[],[]]

for m in range (0, 5):
    msg = bytearray([m]*8) #simpleserial uses bytearrays
    print(msg)

    target.simpleserial_write('h',msg)
    good_output=target.simpleserial_read('r', 4)
    print("Good output:", list(good_output))

    for repeat in range (1,2):
        for offset in range (1,300): 
            scope.glitch.repeat =repeat
            scope.glitch.ext_offset =offset        

            try:


                scope.arm()
                target.simpleserial_write('h',msg)
                ret = scope.capture()
                #print(ret)
                out_arr=target.simpleserial_read('r', 4)

                if (out_arr != good_output):
                    print("Winner Code:", list(out_arr))
                    print('Repeat : %d, offset:  %d, i: %d' %(repeat, offset, i))
                    win_codes[m].append(str(list(out_arr)))
                    #break
                #else:
                    #l=1
                    #print(out_arr)


                    '''if (out_arr != None): 
                        print('Not Broken')
                        signal=scope.get_last_trace()

                        out_arr=target.simpleserial_read('r', 4)
                        out_arr_no_rep = list(out_arr)
                        #print(out_arr)
                        print(out_arr_no_rep)
                        #plot.send(signal[0:500])
                        plt.plot( signal[0:200].T, label ='Trace %d' %i ) # Unit = milliWatt, hence the scaling

                        leg = axes.legend(loc ="upper right");''' 
            except:
                #print('Broken')
                reboot_flush()
    
print(win_codes)   
'''scope.dis()
target.dis()
# %run "../../../jupyter/Setup_Scripts/Setup_Generic.ipynb"
scope._cwusb.usbtx.rep = 0x81
scope._cwusb.usbtx.wep = 0x02'''
# Out:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# CWbytearray(b'00 00 00 00 00 00 00 00')
# Good output: [105, 223, 34, 101]
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  35, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  141, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  145, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  151, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  158, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  168, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  172, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# Winner Code: [11, 141, 245, 124]
# Repeat : 1, offset:  182, i: 0
# Winner Code: [11, 141, 245, 124]
# Repeat : 1, offset:  183, i: 0
# Winner Code: [11, 141, 245, 124]
# Repeat : 1, offset:  184, i: 0
# Winner Code: [11, 141, 245, 124]
# Repeat : 1, offset:  185, i: 0
# Winner Code: [11, 141, 245, 124]
# Repeat : 1, offset:  186, i: 0
# Winner Code: [11, 141, 245, 124]
# Repeat : 1, offset:  187, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [207, 92, 71, 57]
# Repeat : 1, offset:  193, i: 0
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  206, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [7, 225, 36, 0]
# Repeat : 1, offset:  210, i: 0
# Winner Code: [7, 225, 36, 0]
# Repeat : 1, offset:  211, i: 0
# Winner Code: [7, 225, 36, 0]
# Repeat : 1, offset:  212, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# Winner Code: [7, 225, 36, 0]
# Repeat : 1, offset:  220, i: 0
# Winner Code: [7, 225, 36, 0]
# Repeat : 1, offset:  221, i: 0
# Winner Code: [7, 225, 36, 0]
# Repeat : 1, offset:  222, i: 0
# Winner Code: [7, 225, 36, 0]
# Repeat : 1, offset:  223, i: 0
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  224, i: 0
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  231, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  233, i: 0
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  234, i: 0
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  235, i: 0
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  236, i: 0
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  237, i: 0
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  238, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  241, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  265, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  281, i: 0
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  282, i: 0
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  283, i: 0
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  284, i: 0
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  285, i: 0
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  286, i: 0
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  287, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  288, i: 0
# Winner Code: [239, 214, 100, 19]
# Repeat : 1, offset:  289, i: 0
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# CWbytearray(b'01 01 01 01 01 01 01 01')
# Good output: [211, 34, 161, 46]
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# ...
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  203, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  212, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  221, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  231, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  237, i: 0
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  238, i: 0
# WARNING:ChipWhisperer Target:Unexpected start to command:
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# Winner Code: [87, 73, 78, 33]
# Repeat : 1, offset:  268, i: 0
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'RE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'SE'
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: 'T '
# WARNING:ChipWhisperer Target:ValueError: invalid literal for int() with base 16: '  '
# ERROR:ChipWhisperer Target:Target did not ack
# WARNING:ChipWhisperer Target:Unexpected start to command:
# ERROR:ChipWhisperer Target:Target did not ack
# [['[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[11, 141, 245, 124]', '[11, 141, 245, 124]', '[11, 141, 245, 124]', '[11, 141, 245, 124]', '[11, 141, 245, 124]', '[11, 141, 245, 124]', '[207, 92, 71, 57]', '[87, 73, 78, 33]', '[7, 225, 36, 0]', '[7, 225, 36, 0]', '[7, 225, 36, 0]', '[7, 225, 36, 0]', '[7, 225, 36, 0]', '[7, 225, 36, 0]', '[7, 225, 36, 0]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[239, 214, 100, 19]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[239, 214, 100, 19]', '[239, 214, 100, 19]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[239, 214, 100, 19]', '[239, 214, 100, 19]', '[239, 214, 100, 19]', '[239, 214, 100, 19]', '[239, 214, 100, 19]', '[239, 214, 100, 19]', '[239, 214, 100, 19]', '[239, 214, 100, 19]', '[239, 214, 100, 19]'], ['[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]'], ['[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]'], ['[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[254, 101, 224, 187]', '[254, 101, 224, 187]', '[87, 73, 78, 33]', '[254, 101, 224, 187]', '[254, 101, 224, 187]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[146, 226, 78, 185]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[144, 179, 100, 184]', '[87, 73, 78, 33]', '[254, 103, 224, 187]', '[146, 226, 78, 185]', '[146, 226, 78, 185]', '[146, 226, 78, 185]', '[146, 226, 78, 185]'], ['[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]', '[87, 73, 78, 33]']]
# 'scope.dis()\ntarget.dis()\n%run "../../../jupyter/Setup_Scripts/Setup_Generic.ipynb"\nscope._cwusb.usbtx.rep = 0x81\nscope._cwusb.usbtx.wep = 0x02'

# %%
intersection = set.intersection(set(win_codes[0]), set(win_codes[1]), set(win_codes[2]), set(win_codes[3]), set(win_codes[4]))

print("Correct Winner code", str(intersection)[2:-2])
# Out:
# Correct Winner code [87, 73, 78, 33]

# %%
set(win_codes[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-113ff3a7166d> in <module>
# ----> 1 set(win_codes[0])
#
# TypeError: unhashable type: 'list'
